# %% [markdown]
# # Matplotlib 2
# Luis e Pedro

# %% [markdown]
# ## Salvar a figura no disco

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
resultado_1 = [92, 55, 34, 28]
resultado_2 = [82, 80, 77, 85]

# %%
plt.plot(resultado_1, label='hospital 1', marker=0);
plt.plot(resultado_2, label='hospital 2', marker='o');

plt.title('comparação entre hospitais', loc='left');

plt.ylabel('% de ocupação de leito');

plt.legend();

plt.xticks([]);

# %%
plt.savefig('figura.png')

# %% [markdown]
# Salvando a figura como PNG:

# %%
plt.plot(resultado_1, label='hospital 1', marker=0);
plt.plot(resultado_2, label='hospital 2', marker='o');

plt.title('comparação entre hospitais', loc='left');

plt.ylabel('% de ocupação de leito');

plt.legend();

plt.xticks([]);

plt.savefig('figura_certa.png');

# %% [markdown]
# Salvando a figura como PDF:

# %%
plt.plot(resultado_1, label='hospital 1', marker=0);
plt.plot(resultado_2, label='hospital 2', marker='o');

plt.title('comparação entre hospitais', loc='left');

plt.ylabel('% de ocupação de leito');

plt.legend();

plt.xticks([]);

plt.savefig('figura_certa.pdf');

# %% [markdown]
# Se eu quiser salvar em docx:
# (Não funciona)

# %%
plt.plot(resultado_1, label='hospital 1', marker=0);
plt.plot(resultado_2, label='hospital 2', marker='o');

plt.title('comparação entre hospitais', loc='left');

plt.ylabel('% de ocupação de leito');

plt.legend();

plt.xticks([]);

plt.savefig('figura_certa.docx');
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-7067df2568c0> in <module>
#      10 plt.xticks([]);
#      11
# ---> 12 plt.savefig('figura_certa.docx');
#
# c:\users\luis uzai\appdata\local\programs\python\python38\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     857 def savefig(*args, **kwargs):
#     858     fig = gcf()
# --> 859     res = fig.savefig(*args, **kwargs)
#     860     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     861     return res
#
# c:\users\luis uzai\appdata\local\programs\python\python38\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    2309                 patch.set_edgecolor('none')
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#    2313         if transparent:
#
# ...

# %% [markdown]
# Se eu quiser salvar em jpg:

# %%
plt.plot(resultado_1, label='hospital 1', marker=0);
plt.plot(resultado_2, label='hospital 2', marker='o');

plt.title('comparação entre hospitais', loc='left');

plt.ylabel('% de ocupação de leito');

plt.legend();

plt.xticks([]);

plt.savefig('figura_certa.jpg');

# %% [markdown]
# Se eu quiser salvar em jpeg:

# %%
plt.plot(resultado_1, label='hospital 1', marker=0);
plt.plot(resultado_2, label='hospital 2', marker='o');

plt.title('comparação entre hospitais', loc='left');

plt.ylabel('% de ocupação de leito');

plt.legend();

plt.xticks([]);

plt.savefig('figura_certa.jpeg');

# %% [markdown]
# ## subplots

# %% [markdown]
# Baseado na documentação:
# * https://matplotlib.org/devdocs/gallery/subplots_axes_and_figures/subplots_demo.html#

# %%
import numpy as np

# dados de exemplo
x = np.linspace(0, 2 * np.pi, 400)
y = np.sin(x ** 2)

# %%
fig, ax = plt.subplots()
ax.plot(x, y);
ax.set_title('seno x²');

# %% [markdown]
# E se eu quiser adicionar um gráfico em baixo do meu primeiro gráfico?

# %%
fig, axs = plt.subplots(2)
fig.suptitle('Dois gráficos')

axs[0].set_title('Grafo 1')
axs[0].plot(x, y, color='red')

axs[1].set_title('Grafo 2')
axs[1].plot(x, -y, color='orange');

# %% [markdown]
# Mas... E se eu não quiser essa sobreposição?

# %%
fig, axs = plt.subplots(nrows=2, ncols=1)
fig.suptitle('Dois gráficos')

axs[0].set_title('Grafo 1')
axs[0].plot(x, y, color='red')

axs[1].set_title('Grafo 2')
axs[1].plot(x, -y, color='orange')

plt.tight_layout();

# %% [markdown]
# * https://matplotlib.org/stable/gallery/subplots_axes_and_figures/demo_tight_layout.html

# %% [markdown]
# Como eu faço para ter mais de uma coluna?

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)

ax1.plot(x, y, color='red')
ax2.plot(x, -y, color='orange') 

plt.tight_layout()

# %% [markdown]
# E se a gente quiser gerar 4 gráficos: onde temos 2 linhas e 2 colunas:

# %%
fig, axs = plt.subplots(nrows=2, ncols=2)

axs[0, 0].set_title('grafico [0, 0]')
axs[0, 0].plot(x, y)

axs[0, 1].set_title('grafico [0, 1]')
axs[0, 1].plot(x, -y, color='red')

axs[1, 0].set_title('grafico [1, 0]')
axs[1, 0].plot(x, y**2, color='orange')

axs[1, 1].set_title('grafico [1, 1]')
axs[1, 1].plot(x, y**3, color='green')

plt.tight_layout()

# %% [markdown]
# Para guiá-los na escolha das cores:
#
# * https://matplotlib.org/stable/tutorials/colors/colors.html

# %%
fig, axs = plt.subplots(nrows=2, ncols=2)

axs[0, 0].set_title('grafico [0, 0]')
axs[0, 0].plot(x, y)

axs[0, 1].set_title('grafico [0, 1]')
axs[0, 1].plot(x, -y, color='red')

axs[1, 0].set_title('grafico [1, 0]')
axs[1, 0].plot(x, y**2, color='orange')

axs[1, 1].set_title('grafico [1, 1]')
axs[1, 1].plot(x, y**3, color='green')

plt.tight_layout()

# axs.flat: transforma o meu axs em um array de uma dimensão shape=(n, 1)
for ax in axs.flat:
    ax.set_title('');

# %% [markdown]
# Iterar por todos os items:

# %%
fig, axs = plt.subplots(nrows=2, ncols=3)

for index_0 in range(axs.shape[0]):
    for index_1 in range(axs.shape[1]):
        axs[index_0, index_1].set_title('grafico ['  +str(index_0) + ', ' + str(index_1) + ']')
        axs[index_0, index_1].plot(x, y)
        
plt.tight_layout();

# %%
fig, axs = plt.subplots(nrows=2, ncols=3)

for indice, ax in np.ndenumerate(axs):
    ax.set_title(f'Grafico {indice}')
    ax.plot(x, y)
    
plt.tight_layout()

# %% [markdown]
# E se quisesse um gráfico na primeira linha e dois na segunda:

# %%
gridsize = (2, 2)

ax1 = plt.subplot2grid(gridsize, (0, 0), colspan=2)
ax2 = plt.subplot2grid(gridsize, (1, 0))
ax3 = plt.subplot2grid(gridsize, (1, 1))

ax1.plot(x, y, color='red')
ax2.plot(x, y, color='orange')
ax3.plot(x, y)

plt.tight_layout()
