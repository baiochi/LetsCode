# %% [markdown]
# Exercícios de Spark

# %% [markdown]
# 1- Cheque o Spark Context e o Spark Session

# %% [markdown]
# 2- Criar pasta `spark-ex` no diretório `/FileStore` (caminho da pasta `/FileStore/spark-ex`) e fazer upload do arquivo `ds_salaries.csv` nessa nova pasta criada.

# %% [markdown]
# 3- Criar objeto **RDD** a partir do csv `ds_salaries.csv` usando `SparkContext`.

# %% [markdown]
# 4- Agora importe o mesmo arquivo csv usando **pyspark** (`SparkSession`) e salvar na variável `df_salaries`.

# %% [markdown]
# 5- Selecionar a coluna de `localização da empresa`(<i>Explore as colunas</i>) e salvar na variavel `countries_df`.

# %% [markdown]
# 6- Qual a quantidade de países distintos da coluna selecionada anteriormente?

# %% [markdown]
# 7- Selecionar todos os registros em que a empresa se localiza nos `Estados Unidos(US)` mas que os empregados não são americanos.

# %% [markdown]
# 8- Agrupe o DataFrame `df_salaries` por `company_location` e conte a quantidade de registros por país, qual é o país com maior número de registros?(Ordene pela coluna `count`)
